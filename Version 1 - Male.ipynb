# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import cv2

dim = (224, 224)

Test_data = []
Test_chest = []
Test_Long_arm_length = []
Test_Short_arm_length = []
Test_3over4_arm_length = []
Test_Shoulder = []
Test_1over2_length = []
Test_Full_Length = []
Test_Round_neck = []
Test_Bust = []
Test_Under_Bust = []
Test_Waist = []
Test_Hips = []
Test_Trouser_Length = []
Test_Tigh = []
Test_Knee_Length = []
Test_Knee = []
Test_Round_Sleeve = []
Test_Wrist = []
Test_Ankle = []
Test_Back = []
Test_Calf = []
Test_Arm_Hole = []
Test_Bust_Span = []
Test_Bust_Apex = []
Test_Waist_to_Hips = []

mypath = r'C:\Users\Justincul\Documents\Bracket_Stuff\Final_year_project\prototype_test\Male'
Test_files = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = np.zeros((len(Test_files),224*224))
for n in range(0, len(Test_files)):
    #print(Test_files[n]) #Prints the image names in the stated folder
    image =  cv2.imread( join(mypath, Test_files[n]) )
    image = cv2.resize (image, dim)
    feature_matrix = np.zeros(dim)
    features = np.reshape(image, (224*224*3))
    for i in range(0,image.shape[0]):
        for j in range(0, image.shape[1]):
            feature_matrix[i][j] = ((int(image[i, j, 0]) + int(image[i, j, 1]) + int(image[i, j, 2]))/3) 
    
    Test_data.append(features)

# %%
# MALE MEASUREMENTS
#loading the files
import pickle
import os
os.chdir(r'C:\Users\Justincul\Documents\Bracket_Stuff\Final_year_project\SavModels')

chest_filename = 'chest_model.sav'
Long_arm_length_filename = 'Long_arm_length_model.sav'
Short_arm_length_filename = 'Short_arm_length_model.sav'
three_over4_arm_length_filename = '3over4_arm_length_model.sav'
Shoulder_filename = 'Shoulder_model.sav'
one_over2_length_filename = '1over2_length_model.sav'
Full_Length_filename = 'Full_Length_model.sav'
Round_neck_filename = 'Round_neck_model.sav'
Bust_filename = 'Bust_model.sav'
Waist_filename = 'Waist_model.sav'
Trouser_Length_filename = 'Trouser_Length_model.sav'
Tigh_filename = 'Tigh_model.sav'
Knee_Length_filename = 'Knee_Length_model.sav'
Knee_filename = 'Knee_model.sav'
Round_Sleeve_filename = 'Round_Sleeve_model.sav'
Wrist_filename = 'Wrist_model.sav'
Ankle_filename = 'Ankle_model.sav'
Back_filename = 'Back_model.sav'
Calf_filename = 'Calf_model.sav'
Arm_Hole_filename = 'Arm_Hole_model.sav'

Long_arm_length_model = pickle.load(open(Long_arm_length_filename, 'rb'))
Long_arm_length_result = Long_arm_length_model.predict(Test_data)
print('Long arm length result = ', Long_arm_length_result)

Short_arm_length_model = pickle.load(open(Short_arm_length_filename, 'rb'))
Short_arm_length_result = Short_arm_length_model.predict(Test_data)
print('Short arm length result = ', Short_arm_length_result)

three_over4_arm_length_model = pickle.load(open(three_over4_arm_length_filename, 'rb'))
three_over4_arm_length_result = three_over4_arm_length_model.predict(Test_data)
print('3/4 arm length result = ', three_over4_arm_length_result)

Shoulder_model = pickle.load(open(Shoulder_filename, 'rb'))
Shoulder_result = Shoulder_model.predict(Test_data)
print('Shoulder result = ', Shoulder_result)

one_over2_length_model = pickle.load(open(one_over2_length_filename, 'rb'))
one_over2_length_result = chest_model.predict(Test_data)
print('1/2 length result = ', one_over2_length_result)

Full_Length_model = pickle.load(open(Full_Length_filename, 'rb'))
Full_Length_result = Full_Length_model.predict(Test_data)
print('Full Length result = ', Full_Length_result)

Round_neck_model = pickle.load(open(Round_neck_filename, 'rb'))
Round_neck_result = Round_neck_model.predict(Test_data)
print('Round neck result = ', Round_neck_result)

Bust_model = pickle.load(open(Bust_filename, 'rb'))
Bust_result = Bust_model.predict(Test_data)
print('Bust result = ', Bust_result)

Waist_model = pickle.load(open(Waist_filename, 'rb'))
Waist_result = Waist_model.predict(Test_data)
print('Waist result = ', Waist_result)

Trouser_Length_model = pickle.load(open(Trouser_Length_filename, 'rb'))
Trouser_Length_result = Trouser_Length_model.predict(Test_data)
print('Trouser Length result = ', Trouser_Length_result)

Tigh_model = pickle.load(open(Tigh_filename, 'rb'))
Tigh_result = Tigh_model.predict(Test_data)
print('Thigh result = ', Tigh_result)

Knee_Length_model = pickle.load(open(Knee_Length_filename, 'rb'))
Knee_Length_result = Knee_Length_model.predict(Test_data)
print('Knee Length result = ', Knee_Length_result)

Knee_model = pickle.load(open(Knee_filename, 'rb'))
Knee_result = Knee_model.predict(Test_data)
print('Knee result = ', Knee_result)

Round_Sleeve_model = pickle.load(open(Round_Sleeve_filename, 'rb'))
Round_Sleeve_result = Round_Sleeve_model.predict(Test_data)
print('Round Sleeve result = ', Round_Sleeve_result)

Wrist_model = pickle.load(open(Wrist_filename, 'rb'))
Wrist_result = Wrist_model.predict(Test_data)
print('Wrist result = ', Wrist_result)

Ankle_model = pickle.load(open(Ankle_filename, 'rb'))
Ankle_result = Ankle_model.predict(Test_data)
print('Ankle result = ', Ankle_result)

Back_model = pickle.load(open(Back_filename, 'rb'))
Back_result = Back_model.predict(Test_data)
print('Back result = ', Back_result)

Calf_model = pickle.load(open(Calf_filename, 'rb'))
Calf_result = Calf_model.predict(Test_data)
print('Calf result = ', Calf_result)

chest_model = pickle.load(open(chest_filename, 'rb'))
chest_result = chest_model.predict(Test_data)
print('Chest result = ', chest_result)

Arm_Hole_model = pickle.load(open(Arm_Hole_filename, 'rb'))
Arm_Hole_result = Arm_Hole_model.predict(Test_data)
print('Arm Hole result = ', Arm_Hole_result)
# Out:
# chest_result =  [14.145 14.795 13.755]
# Long arm length result =  [28.26  28.18  28.085]
# Short arm length result =  [8.075 7.985 7.995]
# 3/4 arm length result =  [22.24  22.    21.875]
# Shoulder result =  [18.405 18.415 18.465]
# 1/2 length result =  [14.145 14.795 13.755]
# Full Length result =  [62.045 62.2   62.075]
# Round neck result =  [17.765 17.77  17.705]
# Bust result =  [40.26 38.96 37.33]
# Waist result =  [38.25  38.585 38.655]
# Trouser Length result =  [36.48 36.67 36.14]
# Thigh result =  [24.401 24.566 24.581]
# Knee Length result =  [18.21  18.55  19.075]
# Knee result =  [17.52 17.58 17.11]
# Round Sleeve result =  [14.255 14.395 14.43 ]
# Wrist result =  [8.345 8.67  8.65 ]
# Ankle result =  [14.525 14.56  14.6  ]
# Back result =  [22.025 22.09  21.885]
# Calf result =  [15.415 15.21  15.395]
# Arm Hole result =  [23.925 24.215 24.5  ]

# %%
#Combination of the above codes

from os import listdir
from os.path import isfile, join
import numpy as np
import cv2

dim = (224, 224)

Test_data = []
Test_chest = []
Test_Long_arm_length = []
Test_Short_arm_length = []
Test_3over4_arm_length = []
Test_Shoulder = []
Test_1over2_length = []
Test_Full_Length = []
Test_Round_neck = []
Test_Bust = []
Test_Under_Bust = []
Test_Waist = []
Test_Hips = []
Test_Trouser_Length = []
Test_Tigh = []
Test_Knee_Length = []
Test_Knee = []
Test_Round_Sleeve = []
Test_Wrist = []
Test_Ankle = []
Test_Back = []
Test_Calf = []
Test_Arm_Hole = []
Test_Bust_Span = []
Test_Bust_Apex = []
Test_Waist_to_Hips = []

mypath = r'C:\Users\Justincul\Documents\Bracket_Stuff\Final_year_project\prototype_test\Male'
Test_files = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = np.zeros((len(Test_files),224*224))
for n in range(0, len(Test_files)):
    #print(Test_files[n]) #Prints the image names in the stated folder
    image =  cv2.imread( join(mypath, Test_files[n]) )
    image = cv2.resize (image, dim)
    feature_matrix = np.zeros(dim)
    features = np.reshape(image, (224*224*3))
    for i in range(0,image.shape[0]):
        for j in range(0, image.shape[1]):
            feature_matrix[i][j] = ((int(image[i, j, 0]) + int(image[i, j, 1]) + int(image[i, j, 2]))/3) 
    
    Test_data.append(features)

# MALE MEASUREMENTS
#loading the files
import pickle
import os
os.chdir(r'C:\Users\Justincul\Documents\Bracket_Stuff\Final_year_project\SavModels')

chest_filename = 'chest_model.sav'
Long_arm_length_filename = 'Long_arm_length_model.sav'
Short_arm_length_filename = 'Short_arm_length_model.sav'
three_over4_arm_length_filename = '3over4_arm_length_model.sav'
Shoulder_filename = 'Shoulder_model.sav'
one_over2_length_filename = '1over2_length_model.sav'
Full_Length_filename = 'Full_Length_model.sav'
Round_neck_filename = 'Round_neck_model.sav'
Bust_filename = 'Bust_model.sav'
Waist_filename = 'Waist_model.sav'
Trouser_Length_filename = 'Trouser_Length_model.sav'
Tigh_filename = 'Tigh_model.sav'
Knee_Length_filename = 'Knee_Length_model.sav'
Knee_filename = 'Knee_model.sav'
Round_Sleeve_filename = 'Round_Sleeve_model.sav'
Wrist_filename = 'Wrist_model.sav'
Ankle_filename = 'Ankle_model.sav'
Back_filename = 'Back_model.sav'
Calf_filename = 'Calf_model.sav'
Arm_Hole_filename = 'Arm_Hole_model.sav'

Long_arm_length_model = pickle.load(open(Long_arm_length_filename, 'rb'))
Long_arm_length_result = Long_arm_length_model.predict(Test_data)
print('Long arm length result = ', Long_arm_length_result)

Short_arm_length_model = pickle.load(open(Short_arm_length_filename, 'rb'))
Short_arm_length_result = Short_arm_length_model.predict(Test_data)
print('Short arm length result = ', Short_arm_length_result)

three_over4_arm_length_model = pickle.load(open(three_over4_arm_length_filename, 'rb'))
three_over4_arm_length_result = three_over4_arm_length_model.predict(Test_data)
print('3/4 arm length result = ', three_over4_arm_length_result)

Shoulder_model = pickle.load(open(Shoulder_filename, 'rb'))
Shoulder_result = Shoulder_model.predict(Test_data)
print('Shoulder result = ', Shoulder_result)

one_over2_length_model = pickle.load(open(one_over2_length_filename, 'rb'))
one_over2_length_result = one_over2_length_model.predict(Test_data)
print('1/2 length result = ', one_over2_length_result)

Full_Length_model = pickle.load(open(Full_Length_filename, 'rb'))
Full_Length_result = Full_Length_model.predict(Test_data)
print('Full Length result = ', Full_Length_result)

Round_neck_model = pickle.load(open(Round_neck_filename, 'rb'))
Round_neck_result = Round_neck_model.predict(Test_data)
print('Round neck result = ', Round_neck_result)

Bust_model = pickle.load(open(Bust_filename, 'rb'))
Bust_result = Bust_model.predict(Test_data)
print('Bust result = ', Bust_result)

Waist_model = pickle.load(open(Waist_filename, 'rb'))
Waist_result = Waist_model.predict(Test_data)
print('Waist result = ', Waist_result)

Trouser_Length_model = pickle.load(open(Trouser_Length_filename, 'rb'))
Trouser_Length_result = Trouser_Length_model.predict(Test_data)
print('Trouser Length result = ', Trouser_Length_result)

Tigh_model = pickle.load(open(Tigh_filename, 'rb'))
Tigh_result = Tigh_model.predict(Test_data)
print('Thigh result = ', Tigh_result)

Knee_Length_model = pickle.load(open(Knee_Length_filename, 'rb'))
Knee_Length_result = Knee_Length_model.predict(Test_data)
print('Knee Length result = ', Knee_Length_result)

Knee_model = pickle.load(open(Knee_filename, 'rb'))
Knee_result = Knee_model.predict(Test_data)
print('Knee result = ', Knee_result)

Round_Sleeve_model = pickle.load(open(Round_Sleeve_filename, 'rb'))
Round_Sleeve_result = Round_Sleeve_model.predict(Test_data)
print('Round Sleeve result = ', Round_Sleeve_result)

Wrist_model = pickle.load(open(Wrist_filename, 'rb'))
Wrist_result = Wrist_model.predict(Test_data)
print('Wrist result = ', Wrist_result)

Ankle_model = pickle.load(open(Ankle_filename, 'rb'))
Ankle_result = Ankle_model.predict(Test_data)
print('Ankle result = ', Ankle_result)

Back_model = pickle.load(open(Back_filename, 'rb'))
Back_result = Back_model.predict(Test_data)
print('Back result = ', Back_result)

Calf_model = pickle.load(open(Calf_filename, 'rb'))
Calf_result = Calf_model.predict(Test_data)
print('Calf result = ', Calf_result)

chest_model = pickle.load(open(chest_filename, 'rb'))
chest_result = chest_model.predict(Test_data)
print('Chest result = ', chest_result)

Arm_Hole_model = pickle.load(open(Arm_Hole_filename, 'rb'))
Arm_Hole_result = Arm_Hole_model.predict(Test_data)
print('Arm Hole result = ', Arm_Hole_result)
# Out:
# Long arm length result =  [28.26  28.18  28.085]
# Short arm length result =  [8.075 7.985 7.995]
# 3/4 arm length result =  [22.24  22.    21.875]
# Shoulder result =  [18.405 18.415 18.465]
# 1/2 length result =  [23.285 23.47  23.3  ]
# Full Length result =  [62.045 62.2   62.075]
# Round neck result =  [17.765 17.77  17.705]
# Bust result =  [40.26 38.96 37.33]
# Waist result =  [38.25  38.585 38.655]
# Trouser Length result =  [36.48 36.67 36.14]
# Thigh result =  [24.401 24.566 24.581]
# Knee Length result =  [18.21  18.55  19.075]
# Knee result =  [17.52 17.58 17.11]
# Round Sleeve result =  [14.255 14.395 14.43 ]
# Wrist result =  [8.345 8.67  8.65 ]
# Ankle result =  [14.525 14.56  14.6  ]
# Back result =  [22.025 22.09  21.885]
# Calf result =  [15.415 15.21  15.395]
# Chest result =  [14.145 14.795 13.755]
# Arm Hole result =  [23.925 24.215 24.5  ]
